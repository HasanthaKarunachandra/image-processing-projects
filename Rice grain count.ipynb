# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('Samples/hal.jpg')
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.imshow(imgray,cmap='gray')

# %%
ret,thresh=cv2.threshold(imgray,130,255,cv2.THRESH_BINARY)
plt.imshow(thresh,cmap='gray')

# %%
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
print(len(contours))
# Out:
# 66

# %%
for cnt in contours:
    area=cv2.contourArea(cnt)
    print(area)
# Out:
# 486640.0
# 8.5
# 12.5
# 4.0
# 1072.0
# 1165.5
# 1128.5
# 7.0
# 7.0
# 1211.5
# 0.0
# 0.0
# 0.0
# 8.5
# 0.5
# 1076.5
# 0.0
# 1166.5
# 663.0
# 16.5
# 2.0
# 1250.0
# 1205.5
# 1358.0
# 0.0
# 1245.0
# 1148.5
# 1134.5
# 1041.0
# 956.5
# 1284.5
# 991.5
# 0.0
# 0.0
# 0.0
# 6.0
# 2.0
# 925.5
# 900.5
# 7.0
# 676.0
# 1055.0
# 7.0
# 8.5
# 1206.0
# 0.0
# 0.0
# 4.0
# 959.0
# 5.5
# 943.5
# 1135.0
# 1148.5
# 1224.5
# 0.0
# 49.5
# 1084.0
# 10.0
# 6.0
# 10.0
# 17.5
# 1217.5
# 0.0
# 1.5
# 1199.0
# 8.0

# %%
halCount=0
for cnt in contours:
    area=cv2.contourArea(cnt)
    if(area>600 and area<1500):
        cv2.drawContours(img, [cnt], -1, (0,255,0), 2)
        halCount+=1

# %%
# cv2.drawContours(img, contours, -1, (255,255,0), 2)
print(halCount)
plt.imshow(img,cmap='gray')

new_image = cv2.putText(
  img = img,
  text = str(halCount),
  org = (100,100),
  fontFace = cv2.FONT_HERSHEY_DUPLEX,
  fontScale = 3.0,
  color = (0,0,0),
  thickness = 3
)

cv2.imshow('img',img)
cv2.imwrite("hal count.jpg",new_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# 30
